# %%
# Importando as bibliotecas necessárias
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Carregando os dados
df = pd.read_csv('data/processed/data.csv')

# %%
# Mostrando as primeiras linhas do DataFrame
print(df.head())
# Out:
#     Ano/Mês  Entradas - Vendas (R$)  Entradas - Outros (R$)  \
# 0  2022/Jan                  120000                   30000
# 1  2022/Fev                  110000                   25000
# 2  2022/Mar                  115000                   28000
# 3  2022/Abr                  118000                   29000
# 4  2022/Mai                  122000                   31000
#
#    Total Entradas (R$)  Saídas - Salários (R$)  \
# 0               150000                   80000
# 1               135000                   80000
# 2               143000                   81000
# 3               147000                   82000
# 4               153000                   83000
#
#    Saídas - Despesas Operacionais (R$)  Saídas - Investimentos (R$)  \
# 0                                20000                        10000
# 1                                21000                         9500
# 2                                20500                         9800
# 3                                20000                         9900
# 4                                19800                        10200
#
#    Total Saídas (R$)  Fluxo de Caixa Líquido (R$)          Observações
# 0             110000                        40000    Vendas de camisas
# 1             110500                        24500             Carnaval
# 2             113300                        29700   Jogo internacional
# 3             111900                        35100  Final de campeonato
# 4             113000                        40000  Início de temporada

# %%
# Verificando informações básicas do DataFrame
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 10 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Ano/Mês                              24 non-null     object
#  1   Entradas - Vendas (R$)               24 non-null     int64
#  2   Entradas - Outros (R$)               24 non-null     int64
#  3   Total Entradas (R$)                  24 non-null     int64
#  4   Saídas - Salários (R$)               24 non-null     int64
#  5   Saídas - Despesas Operacionais (R$)  24 non-null     int64
#  6   Saídas - Investimentos (R$)          24 non-null     int64
#  7   Total Saídas (R$)                    24 non-null     int64
#  8   Fluxo de Caixa Líquido (R$)          24 non-null     int64
#  9   Observações                          24 non-null     object
# dtypes: int64(8), object(2)
# memory usage: 2.0+ KB
# None

# %%
# Verificando a distribuição das variáveis numéricas
df.describe().transpose()
# Out:
#                                      count           mean          std  \
# Entradas - Vendas (R$)                24.0  127229.166667  7647.078394
# Entradas - Outros (R$)                24.0   31725.000000  2175.006247
# Total Entradas (R$)                   24.0  158954.166667  9762.215499
# Saídas - Salários (R$)                24.0   90541.666667  7002.975558
# Saídas - Despesas Operacionais (R$)   24.0   19104.166667   809.980766
# Saídas - Investimentos (R$)           24.0    9341.666667   582.286846
# Total Saídas (R$)                     24.0  119070.833333  5567.098937
# Fluxo de Caixa Líquido (R$)           24.0   39883.333333  4754.646850
#
#                                           min       25%       50%       75%  \
# Entradas - Vendas (R$)               110000.0  121750.0  127500.0  133250.0
# Entradas - Outros (R$)                25000.0   30950.0   32100.0   33250.0
# Total Entradas (R$)                  135000.0  152700.0  159600.0  166500.0
# Saídas - Salários (R$)                80000.0   84750.0   90500.0   96250.0
# Saídas - Despesas Operacionais (R$)   17900.0   18475.0   19050.0   19625.0
# Saídas - Investimentos (R$)            8300.0    8875.0    9450.0    9825.0
# Total Saídas (R$)                    110000.0  114400.0  119000.0  123600.0
# Fluxo de Caixa Líquido (R$)           24500.0   38900.0   40600.0   42900.0
#
#                                           max
# Entradas - Vendas (R$)               139000.0
# Entradas - Outros (R$)                34400.0
# Total Entradas (R$)                  173400.0
# Saídas - Salários (R$)               102000.0
# Saídas - Despesas Operacionais (R$)   21000.0
# Saídas - Investimentos (R$)           10200.0
# Total Saídas (R$)                    128200.0
# Fluxo de Caixa Líquido (R$)           45200.0

# %%
# Visualizando a distribuição das características principais
sns.pairplot(df)

# %%
# Verifica a correlação entre as variáveis
corr = df.corr()
sns.heatmap(corr, annot=True, cmap='coolwarm')
# Out:
# C:\Users\EmersonLas\AppData\Local\Temp\ipykernel_20700\2669160766.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = df.corr()
# <Axes: >
